# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestoaguaysol-unpaz/sistemas-inteligentes-2026/blob/main/02_redes_neuronales/000_suma_2_numeros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import tensorflow as tf

import matplotlib.pyplot as plt

# %%
X = np.array([
    [2, 2],
    [3, 8],
    [31, 6]
])
y = np.array([
    4,
    11,
    37
])

# %%
# Creación de un modelo usando la API Sequential
# Una capa Densa seguida de otra
modelo = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(2,), activation="linear")
])

# %%
# Compilar el modelo: definir un optimizador, función de pérdida y métricas.
modelo.compile(
    # https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.0001),
    loss="mae",
    metrics=["mae"],
)

# %%
modelo.summary()

# %%
modelo.layers

# %%
modelo.layers[0]

# %%
modelo.layers[0].get_weights()

# %%
# Ver con distintos batch_size cómo avanza cada epoch
modelo.fit(X, y, batch_size=1, epochs=10)

# %%
modelo_fit = modelo.fit(X, y, batch_size=1, epochs=500, verbose=0)

# %%
plt.plot(modelo_fit.history['mae'])

# %%
modelo.layers[0].get_weights()

# %%
modelo.predict(X)

# %%
modelo.evaluate(X, y)
